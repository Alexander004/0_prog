# %%
import pandas as pd
df = pd.read_csv("Data/StarWars.csv", sep = ";")
df
# Out:
#       respondentID seen  fan gender age_group             income  \
# 0       3292879998   да   да      М     18-29                NaN
# 1       3292879538  нет  NaN      М     18-29         0 - 24.999
# 2       3292765271   да  нет      М     18-29         0 - 24.999
# 3       3292763116   да   да      М     18-29  100.000 - 149.999
# 4       3292731220   да   да      М     18-29  100.000 - 149.999
# ...            ...  ...  ...    ...       ...                ...
# 1181    3288388730   да   да      Ж     18-29         0 - 24.999
# 1182    3288378779   да   да      Ж     30-44    50.000 - 99.999
# 1183    3288375286  нет  NaN      Ж     30-44    50.000 - 99.999
# 1184    3288373068   да   да      Ж     45-60  100.000 - 149.999
# 1185    3288372923   да  нет      Ж      > 60    50.000 - 99.999
#
#                                loc                      yoda  \
# 0               Южно-Атлантический            очень нравится
# ...

# %%
df1 = df[(df["age_group"] == "18-29") & (df["fan"]=="нет")]
df1["loc"].unique().size
for region in df1["loc"].unique():
    print(region, df1[df1["loc"] == region])
# Out:
# Северо-Западный центральный      respondentID seen  fan gender age_group           income  \
# 2      3292765271   да  нет      М     18-29       0 - 24.999
# 149    3291312980   да  нет      Ж     18-29       0 - 24.999
# 521    3290342169   да  нет      М     18-29  50.000 - 99.999
# 696    3289905986   да  нет      Ж     18-29       0 - 24.999
# 868    3289505557   да  нет      Ж     18-29  25.000 - 49.999
# 974    3288714697   да  нет      Ж     18-29       0 - 24.999
#
#                              loc                      yoda  \
# 2    Северо-Западный центральный  не знаю такого персонажа
# 149  Северо-Западный центральный            очень нравится
# 521  Северо-Западный центральный            очень нравится
# 696  Северо-Западный центральный            очень нравится
# 868  Северо-Западный центральный                  нравится
# 974  Северо-Западный центральный                  нравится
#
#     princess_leia_organa
# 2               нравится
# 149             нравится
# ...

# %%
for region in df["loc"].unique():
    print(region, df[df["loc"] == region].size)
# Out:
# Южно-Атлантический 1530
# Юго-Западный центральный 990
# Северо-Западный центральный 837
# Средне-Атлантический 1098
# Северо-Восточный центральный 1629
# Тихоокеанский 1575
# nan 0
# Горный 711
# Новая Англия 675
# Юго-Восточный центральный 342

# %%
df['yoda'].info()
print(1186-826)
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1186 entries, 0 to 1185
# Series name: yoda
# Non-Null Count  Dtype
# --------------  -----
# 826 non-null    object
# dtypes: object(1)
# memory usage: 9.4+ KB
# 360

# %%
df[(df["loc"]=="Новая Англия")&(df["princess_leia_organa"]=="очень нравится")].shape
# Out:
# (39, 9)
